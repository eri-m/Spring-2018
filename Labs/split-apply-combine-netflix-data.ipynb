# %% [markdown]
# # Lab3: split-apply-combine in pandas & data visualization

# %% [markdown]
# Question:
#
# Do Netflix subscribers prefer older or newer movies? Are there other factors that affect this preference such as *rating*?
#
# Task:
#
# - Split the dataset into groups, one for each year, and then to compute one or several summary statistics.
# - See whether this statistic increases over the years.
#
#
# Source: https://github.com/datacamp/community-groupby

# %% [markdown]
# ## Data Exploration with pandas

# %% [markdown]
# ### Import your data

# %%
# Import packages and set visualization style
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()
# %matplotlib inline

# %%
# Import data and check out head of DataFrame
df = pd.read_csv('netflix.csv')
df.tail()
# Out:
#                        title rating  \
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratinglevel  ratingdescription  \
# 995  for action/peril, some scary moments and brief...                 60
# 996                     for action and some rude humor                 60
# 997                             Suitable for all ages.                 35
# 998                             Suitable for all ages.                 35
# 999                                                NaN                 35
#
#      release_year  user_rating_score  user_rating_size
# 995          2016               97.0                80
# 996          2016                NaN                81
# 997          2003                NaN                82
# 998          2013                NaN                82
# 999          2016               80.0                80

# %% [markdown]
# ### Data Exploratory Analysis

# %% [markdown]
# Applying `pandas` DataFrame `.info()` below shows that you have 1000 rows and 7 columns of data, but also that the column of interest, `user_rating_score`, has only 605 non-null values. This means that there are 395 missing values:

# %%
# Check out info of DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# title                1000 non-null object
# rating               1000 non-null object
# ratinglevel          941 non-null object
# ratingdescription    1000 non-null int64
# release_year         1000 non-null int64
# user_rating_score    605 non-null float64
# user_rating_size     1000 non-null int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %% [markdown]
# ### Dispersion Matrix plot

# %%
# Drop rows with missing values and drop duplicate
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# Visualize pairplot of df (similar to pairs() in R)
sns.pairplot(df, hue='rating');

# %%
sns.pairplot?

# %%
# Get summary stats of df
df.describe()
# Out:
#        ratingdescription  release_year  user_rating_score  user_rating_size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %% [markdown]
# ## Groupby (split-apply-combine) to answer the question

# %% [markdown]
# <a id='step_1'></a>

# %% [markdown]
# Let us first use a *groupby* method to split the data into groups, where each group is the set of movies released in a given year.

# %%
# Group by year
df_by_year = df.groupby('release_year')

# %% [markdown]
# This creates a *groupby* object:

# %%
# Check type of GroupBy object
type(df_by_year)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %% [markdown]
# Let us compute summary statistics of our response variable `user_rating_score` in order to capture the main characteristics for each value of `release_year`.

# %%
(df.groupby('release_year')
    .describe())
# Out:
#                     ratingdescription  user_rating_score  user_rating_size
# release_year
# 1940         count           1.000000           1.000000               1.0
#              mean           35.000000          61.000000              80.0
#              std                  NaN                NaN               NaN
#              min            35.000000          61.000000              80.0
#              25%            35.000000          61.000000              80.0
#              50%            35.000000          61.000000              80.0
#              75%            35.000000          61.000000              80.0
#              max            35.000000          61.000000              80.0
# 1978         count           1.000000           1.000000               1.0
#              mean           60.000000          86.000000              80.0
#              std                  NaN                NaN               NaN
#              min            60.000000          86.000000              80.0
#              25%            60.000000          86.000000              80.0
#              50%            60.000000          86.000000              80.0
#              75%            60.000000          86.000000              80.0
#              max            60.000000          86.000000              80.0
# 1982         count           1.000000           1.000000               1.0
#              mean           60.000000          68.000000              80.0
#              std                  NaN                NaN               NaN
#              min            60.000000          68.000000              80.0
#              25%            60.000000          68.000000              80.0
#              50%            60.000000          68.000000              80.0
#              75%            60.000000          68.000000              80.0
#              max            60.000000          68.000000              80.0
# 1986         count           1.000000           1.000000               1.0
#              mean           35.000000          67.000000              80.0
#              std                  NaN                NaN               NaN
#              min            35.000000          67.000000              80.0
#              25%            35.000000          67.000000              80.0
#              50%            35.000000          67.000000              80.0
# ...                               ...                ...               ...
# 2014         std            21.368874          13.453342               0.0
#              min            35.000000          57.000000              80.0
#              25%            70.000000          63.000000              80.0
#              50%            80.000000          74.000000              80.0
#              75%            90.000000          84.000000              80.0
#              max           110.000000          94.000000              80.0
# 2015         count          32.000000          32.000000              32.0
#              mean           73.250000          82.750000              80.0
#              std            27.344870          11.919082               0.0
#              min            10.000000          56.000000              80.0
#              25%            60.000000          71.750000              80.0
#              50%            80.000000          83.500000              80.0
#              75%            90.000000          93.250000              80.0
#              max           110.000000          98.000000              80.0
# 2016         count          82.000000          82.000000              82.0
#              mean           84.341463          85.060976              80.0
#              std            23.018629          12.221563               0.0
#              min            10.000000          56.000000              80.0
#              25%            70.000000          77.250000              80.0
#              50%            90.000000          90.000000              80.0
#              75%           100.000000          95.000000              80.0
#              max           124.000000          98.000000              80.0
# 2017         count          10.000000          10.000000              10.0
#              mean           94.300000          87.000000              80.0
#              std            28.519194           8.096639               0.0
#              min            41.000000          72.000000              80.0
#              25%            95.000000          81.250000              80.0
#              50%           110.000000          89.000000              80.0
#              75%           110.000000          92.500000              80.0
#              max           110.000000          99.000000              80.0
#
# [256 rows x 3 columns]

# %% [markdown]
# We can depict the above information using a boxplot as follows:

# %%
# Create boxplot  via factor plot
sns.factorplot(x="release_year", y="user_rating_score",data=df, kind="box")

# %% [markdown]
# Let's obtain a summary statistic, such as the mean and the compare agains the exmplanatory variables `release_year` and `rating`.

# %%
(df.groupby(['release_year','rating'])
   .median())
# Out:
#                        ratingdescription  user_rating_score  user_rating_size
# release_year rating
# 1940         G                        35               61.0                80
# 1978         PG                       60               86.0                80
# 1982         PG                       60               68.0                80
# 1986         G                        35               67.0                80
# 1987         PG                       60               58.0                80
# 1989         PG                       60               80.0                80
# 1990         TV-Y7                    41               65.0                80
# 1992         G                        35               70.0                80
# 1993         G                        35               96.0                80
#              PG                       60               82.5                80
# 1994         PG                       60               78.5                80
# 1995         G                        35               64.0                80
#              PG                       60               74.0                80
# 1997         G                        35               93.0                80
#              PG                       60               79.0                80
#              TV-Y                     10               81.0                80
#              TV-Y7                    41               72.0                80
# 1998         PG                       60               80.5                80
#              PG-13                    80               82.0                80
#              TV-G                     35               64.0                80
#              TV-Y7                    41               88.0                80
# 1999         G                        35               81.0                80
#              PG                       60               83.0                80
#              PG-13                    80               68.0                80
# 2000         G                        35               87.5                80
#              PG                       60               91.0                80
#              TV-Y                     10               74.0                80
# 2001         PG                       60               96.0                80
#              R                       100               78.0                80
# 2002         PG                       60               90.5                80
# ...                                  ...                ...               ...
# 2013         TV-14                    90               77.0                80
#              TV-MA                   110               96.0                80
#              TV-Y                     10               81.0                80
# 2014         G                        35               57.0                80
#              PG                       60               70.0                80
#              TV-14                    90               74.0                80
#              TV-MA                   110               63.0                80
#              TV-PG                    70               93.0                80
# 2015         PG                       60               91.5                80
#              R                       100               79.0                80
#              TV-14                    90               81.0                80
#              TV-G                     35               86.0                80
#              TV-MA                   110               90.5                80
#              TV-PG                    70               88.5                80
#              TV-Y                     10               75.0                80
#              TV-Y7-FV                 42               61.5                80
# 2016         NR                      124               97.0                80
#              PG                       60               94.5                80
#              R                       100               93.5                80
#              TV-14                    90               87.0                80
#              TV-G                     35               61.0                80
#              TV-MA                   110               89.0                80
#              TV-PG                    70               96.0                80
#              TV-Y                     10               77.0                80
#              TV-Y7                    41               85.0                80
#              TV-Y7-FV                 42               78.0                80
# 2017         TV-14                    90               91.0                80
#              TV-MA                   110               90.0                80
#              TV-Y7                    41               72.0                80
#              TV-Y7-FV                 42               88.0                80
#
# [101 rows x 3 columns]

# %%
df_median = (df.groupby(['release_year','rating'])
               .apply(lambda x:x.user_rating_score.median())) # behaves similar to summarise()
df_median.head()
# Out:
# release_year  rating
# 1940          G         61.0
# 1978          PG        86.0
# 1982          PG        68.0
# 1986          G         67.0
# 1987          PG        58.0
# dtype: float64

# %%
# To apply an arbitrary function the lambda function should return a new series
df1 = (df.groupby(['release_year','rating'])
               .apply(lambda x:pd.Series({'median_score':x.user_rating_score.median()})))
df1.head()
# Out:
#                      median_score
# release_year rating
# 1940         G               61.0
# 1978         PG              86.0
# 1982         PG              68.0
# 1986         G               67.0
# 1987         PG              58.0

# %% [markdown]
# ## `%>%`'ing in pandas
#
# - Method chaining means to call methods on an object one after another -- it is very popular in data science.
#
# - Suppose we now want to compute an arbitrary function (e.g., the IQR) and the median along all possible values of `release_year` and `rating` for which the number of observations is positive.

# %%
# To apply an arbitrary function the lambda function should return a new series
df2 = (df.groupby(['release_year','rating']) # combine step
               .apply(lambda x:pd.Series({'n':x.user_rating_score.count(),
                                          'median':x.user_rating_score.median(),
                                          'q1':x.user_rating_score.quantile(0.25),
                                          'q3':x.user_rating_score.quantile(0.75)}))
               .query('n>0') # similar to filter() in dplyr
               .assign(IQR_score=lambda x: x.q3-x.q1) # similar to mutate() in dplyr
      .sort_index()) 
df2
# Out:
#                        median     n     q1     q3  IQR_score
# release_year rating
# 1940         G           61.0   1.0  61.00  61.00       0.00
# 1978         PG          86.0   1.0  86.00  86.00       0.00
# 1982         PG          68.0   1.0  68.00  68.00       0.00
# 1986         G           67.0   1.0  67.00  67.00       0.00
# 1987         PG          58.0   1.0  58.00  58.00       0.00
# 1989         PG          80.0   1.0  80.00  80.00       0.00
# 1990         TV-Y7       65.0   1.0  65.00  65.00       0.00
# 1992         G           70.0   1.0  70.00  70.00       0.00
# 1993         G           96.0   1.0  96.00  96.00       0.00
#              PG          82.5   2.0  81.75  83.25       1.50
# 1994         PG          78.5   4.0  70.75  87.75      17.00
# 1995         G           64.0   1.0  64.00  64.00       0.00
#              PG          74.0   1.0  74.00  74.00       0.00
# 1997         G           93.0   1.0  93.00  93.00       0.00
#              PG          79.0   2.0  77.00  81.00       4.00
#              TV-Y        81.0   1.0  81.00  81.00       0.00
#              TV-Y7       72.0   1.0  72.00  72.00       0.00
# 1998         PG          80.5   2.0  80.25  80.75       0.50
#              PG-13       82.0   1.0  82.00  82.00       0.00
#              TV-G        64.0   1.0  64.00  64.00       0.00
#              TV-Y7       88.0   1.0  88.00  88.00       0.00
# 1999         G           81.0   2.0  74.00  88.00      14.00
#              PG          83.0   1.0  83.00  83.00       0.00
#              PG-13       68.0   1.0  68.00  68.00       0.00
# 2000         G           87.5   2.0  83.75  91.25       7.50
#              PG          91.0   1.0  91.00  91.00       0.00
#              TV-Y        74.0   1.0  74.00  74.00       0.00
# 2001         PG          96.0   1.0  96.00  96.00       0.00
#              R           78.0   1.0  78.00  78.00       0.00
# 2002         PG          90.5   2.0  88.25  92.75       4.50
# ...                       ...   ...    ...    ...        ...
# 2013         TV-14       77.0   6.0  64.75  84.00      19.25
#              TV-MA       96.0   2.0  95.50  96.50       1.00
#              TV-Y        81.0   1.0  81.00  81.00       0.00
# 2014         G           57.0   1.0  57.00  57.00       0.00
#              PG          70.0   1.0  70.00  70.00       0.00
#              TV-14       74.0   4.0  69.25  76.00       6.75
#              TV-MA       63.0   2.0  63.00  63.00       0.00
#              TV-PG       93.0   4.0  90.00  93.25       3.25
# 2015         PG          91.5   6.0  76.50  93.75      17.25
#              R           79.0   1.0  79.00  79.00       0.00
#              TV-14       81.0  11.0  68.50  93.50      25.00
#              TV-G        86.0   2.0  85.00  87.00       2.00
#              TV-MA       90.5   4.0  82.75  98.00      15.25
#              TV-PG       88.5   4.0  84.75  93.25       8.50
#              TV-Y        75.0   2.0  71.50  78.50       7.00
#              TV-Y7-FV    61.5   2.0  58.75  64.25       5.50
# 2016         NR          97.0   1.0  97.00  97.00       0.00
#              PG          94.5  12.0  88.75  97.00       8.25
#              R           93.5   4.0  88.00  96.25       8.25
#              TV-14       87.0  36.0  74.00  95.00      21.00
#              TV-G        61.0   3.0  61.00  75.50      14.50
#              TV-MA       89.0  17.0  80.00  94.00      14.00
#              TV-PG       96.0   4.0  92.75  98.00       5.25
#              TV-Y        77.0   1.0  77.00  77.00       0.00
#              TV-Y7       85.0   1.0  85.00  85.00       0.00
#              TV-Y7-FV    78.0   3.0  74.50  80.50       6.00
# 2017         TV-14       91.0   1.0  91.00  91.00       0.00
#              TV-MA       90.0   7.0  81.50  93.50      12.00
#              TV-Y7       72.0   1.0  72.00  72.00       0.00
#              TV-Y7-FV    88.0   1.0  88.00  88.00       0.00
#
# [101 rows x 5 columns]

# %% [markdown]
# ## From wide to long format

# %% [markdown]
# - We now want to create a line plot `user_rating_score` against `release_year`of the median along with inter-quartile range (i.e., plotting q3 and q1) but identifying each line according to `rating`.
# - To do so, it is more convenient to convert our previous DataFrame object from wide to long format.

# %%
df3 = (pd.melt(df2.reset_index(), # notice that we have to add reset index
              col_level=0,
              id_vars=['release_year','rating'],
              value_vars=['median','q1','q3'],
              value_name='SummaryStatistic'))
df3.head()
# Out:
#    release_year rating variable  SummaryStatistic
# 0          1940      G   median              61.0
# 1          1978     PG   median              86.0
# 2          1982     PG   median              68.0
# 3          1986      G   median              67.0
# 4          1987     PG   median              58.0

# %%
# Another less obscure option using stack()
df2.stack()
# Out:
# release_year  rating
# 1940          G         median       61.0
#                         n             1.0
#                         q1           61.0
#                         q3           61.0
#                         IQR_score     0.0
# 1978          PG        median       86.0
#                         n             1.0
#                         q1           86.0
#                         q3           86.0
#                         IQR_score     0.0
# 1982          PG        median       68.0
#                         n             1.0
#                         q1           68.0
#                         q3           68.0
#                         IQR_score     0.0
# 1986          G         median       67.0
#                         n             1.0
#                         q1           67.0
#                         q3           67.0
#                         IQR_score     0.0
# 1987          PG        median       58.0
#                         n             1.0
#                         q1           58.0
#                         q3           58.0
#                         IQR_score     0.0
# 1989          PG        median       80.0
#                         n             1.0
#                         q1           80.0
#                         q3           80.0
#                         IQR_score     0.0
#                                      ...
# 2016          TV-Y7     median       85.0
#                         n             1.0
#                         q1           85.0
#                         q3           85.0
#                         IQR_score     0.0
#               TV-Y7-FV  median       78.0
#                         n             3.0
#                         q1           74.5
#                         q3           80.5
#                         IQR_score     6.0
# 2017          TV-14     median       91.0
#                         n             1.0
#                         q1           91.0
#                         q3           91.0
#                         IQR_score     0.0
#               TV-MA     median       90.0
#                         n             7.0
#                         q1           81.5
#                         q3           93.5
#                         IQR_score    12.0
#               TV-Y7     median       72.0
#                         n             1.0
#                         q1           72.0
#                         q3           72.0
#                         IQR_score     0.0
#               TV-Y7-FV  median       88.0
#                         n             1.0
#                         q1           88.0
#                         q3           88.0
#                         IQR_score     0.0
# dtype: float64

# %%
df2.stack().reset_index()
# Out:
#      release_year    rating    level_2     0
# 0            1940         G     median  61.0
# 1            1940         G          n   1.0
# 2            1940         G         q1  61.0
# 3            1940         G         q3  61.0
# 4            1940         G  IQR_score   0.0
# 5            1978        PG     median  86.0
# 6            1978        PG          n   1.0
# 7            1978        PG         q1  86.0
# 8            1978        PG         q3  86.0
# 9            1978        PG  IQR_score   0.0
# 10           1982        PG     median  68.0
# 11           1982        PG          n   1.0
# 12           1982        PG         q1  68.0
# 13           1982        PG         q3  68.0
# 14           1982        PG  IQR_score   0.0
# 15           1986         G     median  67.0
# 16           1986         G          n   1.0
# 17           1986         G         q1  67.0
# 18           1986         G         q3  67.0
# 19           1986         G  IQR_score   0.0
# 20           1987        PG     median  58.0
# 21           1987        PG          n   1.0
# 22           1987        PG         q1  58.0
# 23           1987        PG         q3  58.0
# 24           1987        PG  IQR_score   0.0
# 25           1989        PG     median  80.0
# 26           1989        PG          n   1.0
# 27           1989        PG         q1  80.0
# 28           1989        PG         q3  80.0
# 29           1989        PG  IQR_score   0.0
# ..            ...       ...        ...   ...
# 475          2016     TV-Y7     median  85.0
# 476          2016     TV-Y7          n   1.0
# 477          2016     TV-Y7         q1  85.0
# 478          2016     TV-Y7         q3  85.0
# 479          2016     TV-Y7  IQR_score   0.0
# 480          2016  TV-Y7-FV     median  78.0
# 481          2016  TV-Y7-FV          n   3.0
# 482          2016  TV-Y7-FV         q1  74.5
# 483          2016  TV-Y7-FV         q3  80.5
# 484          2016  TV-Y7-FV  IQR_score   6.0
# 485          2017     TV-14     median  91.0
# 486          2017     TV-14          n   1.0
# 487          2017     TV-14         q1  91.0
# 488          2017     TV-14         q3  91.0
# 489          2017     TV-14  IQR_score   0.0
# 490          2017     TV-MA     median  90.0
# 491          2017     TV-MA          n   7.0
# 492          2017     TV-MA         q1  81.5
# 493          2017     TV-MA         q3  93.5
# 494          2017     TV-MA  IQR_score  12.0
# 495          2017     TV-Y7     median  72.0
# 496          2017     TV-Y7          n   1.0
# 497          2017     TV-Y7         q1  72.0
# 498          2017     TV-Y7         q3  72.0
# 499          2017     TV-Y7  IQR_score   0.0
# 500          2017  TV-Y7-FV     median  88.0
# 501          2017  TV-Y7-FV          n   1.0
# 502          2017  TV-Y7-FV         q1  88.0
# 503          2017  TV-Y7-FV         q3  88.0
# 504          2017  TV-Y7-FV  IQR_score   0.0
#
# [505 rows x 4 columns]

# %%
df3 = (df2.stack()
    .reset_index()
    .rename(index=str, columns={"level_2": "SummaryStatistic", 0: "value"}))
df3
# Out:
#      release_year    rating SummaryStatistic  value
# 0            1940         G           median   61.0
# 1            1940         G                n    1.0
# 2            1940         G               q1   61.0
# 3            1940         G               q3   61.0
# 4            1940         G        IQR_score    0.0
# 5            1978        PG           median   86.0
# 6            1978        PG                n    1.0
# 7            1978        PG               q1   86.0
# 8            1978        PG               q3   86.0
# 9            1978        PG        IQR_score    0.0
# 10           1982        PG           median   68.0
# 11           1982        PG                n    1.0
# 12           1982        PG               q1   68.0
# 13           1982        PG               q3   68.0
# 14           1982        PG        IQR_score    0.0
# 15           1986         G           median   67.0
# 16           1986         G                n    1.0
# 17           1986         G               q1   67.0
# 18           1986         G               q3   67.0
# 19           1986         G        IQR_score    0.0
# 20           1987        PG           median   58.0
# 21           1987        PG                n    1.0
# 22           1987        PG               q1   58.0
# 23           1987        PG               q3   58.0
# 24           1987        PG        IQR_score    0.0
# 25           1989        PG           median   80.0
# 26           1989        PG                n    1.0
# 27           1989        PG               q1   80.0
# 28           1989        PG               q3   80.0
# 29           1989        PG        IQR_score    0.0
# ..            ...       ...              ...    ...
# 475          2016     TV-Y7           median   85.0
# 476          2016     TV-Y7                n    1.0
# 477          2016     TV-Y7               q1   85.0
# 478          2016     TV-Y7               q3   85.0
# 479          2016     TV-Y7        IQR_score    0.0
# 480          2016  TV-Y7-FV           median   78.0
# 481          2016  TV-Y7-FV                n    3.0
# 482          2016  TV-Y7-FV               q1   74.5
# 483          2016  TV-Y7-FV               q3   80.5
# 484          2016  TV-Y7-FV        IQR_score    6.0
# 485          2017     TV-14           median   91.0
# 486          2017     TV-14                n    1.0
# 487          2017     TV-14               q1   91.0
# 488          2017     TV-14               q3   91.0
# 489          2017     TV-14        IQR_score    0.0
# 490          2017     TV-MA           median   90.0
# 491          2017     TV-MA                n    7.0
# 492          2017     TV-MA               q1   81.5
# 493          2017     TV-MA               q3   93.5
# 494          2017     TV-MA        IQR_score   12.0
# 495          2017     TV-Y7           median   72.0
# 496          2017     TV-Y7                n    1.0
# 497          2017     TV-Y7               q1   72.0
# 498          2017     TV-Y7               q3   72.0
# 499          2017     TV-Y7        IQR_score    0.0
# 500          2017  TV-Y7-FV           median   88.0
# 501          2017  TV-Y7-FV                n    1.0
# 502          2017  TV-Y7-FV               q1   88.0
# 503          2017  TV-Y7-FV               q3   88.0
# 504          2017  TV-Y7-FV        IQR_score    0.0
#
# [505 rows x 4 columns]
